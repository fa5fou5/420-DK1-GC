# %%
# %pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/fc/a5/4d82be566f069d7a9a702dcdf6f9106df0e0b042e738043c0cc7ddd7e3f6/pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/9c/3d/a121f284241f08268b21359bd425f7d4825cffc5ac5cd0e1b3d82ffd2b10/pytz-2024.1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/65/58/f9c9e6be752e9fcb8b6a0ee9fb87e6e7a1f6bcab2cdc73f02bb7ba91ada0/tzdata-2024.1-py2.py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 15.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 8.7 MB/s eta 0:00:000m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 21.5 MB/s eta 0:00:00
# ...

# %%
import pandas
import numpy

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

# %%
type(mydataset)
# Out:
# dict

# %%
mydataset.keys()
# Out:
# dict_keys(['cars', 'passings'])

# %%
mydataset.values()
# Out:
# dict_values([['BMW', 'Volvo', 'Ford'], [3, 7, 2]])

# %%
mydataset['cars']
# Out:
# ['BMW', 'Volvo', 'Ford']

# %%
mydataset['passings'], type(mydataset['passings'])
# Out:
# ([3, 7, 2], list)

# %%
myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
myvar
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd
import numpy as np

# %%
myvar = pd.DataFrame(mydataset)

# %%
myvar
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
pip = 3

# %%
pip
# Out:
# 3

# %%
a = [1, 7, 2]

# %%
a[0]
# Out:
# 1

# %%
myvar = pd.Series(a)

# %%
myvar
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
myvar[1]
# Out:
# 7

# %%
print(myvar[0])
# Out:
# 1

# %%
vect = np.array(a)

# %%
vect
# Out:
# array([1, 7, 2])

# %%
myvect = pd.Series(vect)

# %%
myvect
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
myvar = pd.Series(a, index = ["x", "y", "z"])

# %%
myvar
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
myvar['x']
# Out:
# 1

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

# %%
type(calories)
# Out:
# dict

# %%
myvar = pd.Series(calories)

# %%
myvar
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
myvar = pd.Series(calories, index = ["day1", "day3"])

# %%
myvar
# Out:
# day1    420
# day3    390
# dtype: int64

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

# %%
myvar
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

# %%
myvar = pd.Series(calories)
myvar
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
calories = {"day1": [420], "day2": [380], "day3": [390]}

# %%
myvar = pd.DataFrame(calories)
myvar
# Out:
#    day1  day2  day3
# 0   420   380   390

# %%
calories = {"day1": [420,456], "day2": [380, None], "day3": [390, 478]}

# %%
myvar = pd.DataFrame(calories)
myvar
# Out:
#    day1   day2  day3
# 0   420  380.0   390
# 1   456    NaN   478

# %%
myvar.dtypes
# Out:
# day1      int64
# day2    float64
# day3      int64
# dtype: object

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

# %%
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#refer to the row index:
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#refer to the row index:
print(df.loc[1])
# Out:
# calories    380
# duration     40
# Name: 1, dtype: int64

# %%
#use a list of indexes:
print(df.loc[[0, 2]])
# Out:
#    calories  duration
# 0       420        50
# 2       390        45

# %%
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

# %%
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
#refer to the named index:
print(df.loc["day1"])
# Out:
# calories    420
# duration     50
# Name: day1, dtype: int64

# %%
type(df.loc["day1"])
# Out:
# pandas.core.series.Series

# %%
#refer to the named index:
print(df.loc[["day1"]])
# Out:
#       calories  duration
# day1       420        50

# %%
type(df.loc[["day1"]])
# Out:
# pandas.core.frame.DataFrame

# %%
#refer to the named index:
print(df.loc[["day2", "day1"]])
# Out:
#       calories  duration
# day2       380        40
# day1       420        50

# %%
df_file = pd.read_csv('data.csv')

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows = 60

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df_json = pd.read_json('data.json')

# %%
df_json
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(df_json.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
print(df_file.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(df_file.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
print(df_file.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
df_error = pd.read_csv('data_error.csv',delimiter = ';')

# %%
df_error
# Out:
#     Duration          Date  Pulse  Maxpulse Calories
# 0         60  <2020/12/01>    110       130    409.1
# 1         60  '2020/12/02'    117       145    479.0
# 2         60  '2020/12/03'    103       135    340.0
# 3         45  '2020/12/04'    109       175    282.4
# 4         45  '2020/12/05'    117       148    406.0
# 5         60  '2020/12/06'    102       127    300.0
# 6         60  '2020/12/07'    110       136    374.0
# 7        450  '2020/12/08'    104       134    253.3
# 8         30  '2020/12/09'    109       133    195.1
# 9         60  '2020/12/10'     98       124    269.0
# 10        60  '2020/12/11'    103       147    329.3
# 11        60  '2020/12/12'    100       120    250.7
# 12        60  '2020/12/12'    100       120    250.7
# 13        60  '2020/12/13'    106       128    345.3
# 14        60  '2020/12/14'    104       132    379.3
# 15        60  '2020/12/15'     98       123    275.0
# 16        60  '2020/12/16'     98       120    215.2
# ...

# %%
df_error.dropna(inplace = True)

# %%
df_error.fillna(130, inplace = True)

# %%
df_error
# Out:
#     Duration          Date  Pulse  Maxpulse Calories
# 0         60  <2020/12/01>    110       130    409.1
# 1         60  '2020/12/02'    117       145    479.0
# 2         60  '2020/12/03'    103       135    340.0
# 3         45  '2020/12/04'    109       175    282.4
# 4         45  '2020/12/05'    117       148    406.0
# 5         60  '2020/12/06'    102       127    300.0
# 6         60  '2020/12/07'    110       136    374.0
# 7        450  '2020/12/08'    104       134    253.3
# 8         30  '2020/12/09'    109       133    195.1
# 9         60  '2020/12/10'     98       124    269.0
# 10        60  '2020/12/11'    103       147    329.3
# 11        60  '2020/12/12'    100       120    250.7
# 12        60  '2020/12/12'    100       120    250.7
# 13        60  '2020/12/13'    106       128    345.3
# 14        60  '2020/12/14'    104       132    379.3
# 15        60  '2020/12/15'     98       123    275.0
# 16        60  '2020/12/16'     98       120    215.2
# ...

# %%
df_error["Calories"].fillna(130, inplace = True)
# Out:
# /tmp/ipykernel_11415/844259322.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_error["Calories"].fillna(130, inplace = True)

# %%
df_error
# Out:
#     Duration          Date  Pulse  Maxpulse Calories
# 0         60  <2020/12/01>    110       130    409.1
# 1         60  '2020/12/02'    117       145    479.0
# 2         60  '2020/12/03'    103       135    340.0
# 3         45  '2020/12/04'    109       175    282.4
# 4         45  '2020/12/05'    117       148    406.0
# 5         60  '2020/12/06'    102       127    300.0
# 6         60  '2020/12/07'    110       136    374.0
# 7        450  '2020/12/08'    104       134    253.3
# 8         30  '2020/12/09'    109       133    195.1
# 9         60  '2020/12/10'     98       124    269.0
# 10        60  '2020/12/11'    103       147    329.3
# 11        60  '2020/12/12'    100       120    250.7
# 12        60  '2020/12/12'    100       120    250.7
# 13        60  '2020/12/13'    106       128    345.3
# 14        60  '2020/12/14'    104       132    379.3
# 15        60  '2020/12/15'     98       123    275.0
# 16        60  '2020/12/16'     98       120    215.2
# ...
